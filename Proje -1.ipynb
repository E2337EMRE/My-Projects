# %%
pwd
# Out:
# 'C:\\Users\\emre-'

# %%
cd Data_1
# Out:
# C:\Users\emre-\Data_1

# %%
cd clarusway-data-science-5-20-master
# Out:
# C:\Users\emre-\Data_1\clarusway-data-science-5-20-master

# %%
cd 1-projects/
# Out:
# C:\Users\emre-\Data_1\clarusway-data-science-5-20-master\1-projects

# %%
cd 01-EU_DS_DAPy_M1-(TrafficPoliceStops)
# Out:
# C:\Users\emre-\Data_1\clarusway-data-science-5-20-master\1-projects\01-EU_DS_DAPy_M1-(TrafficPoliceStops)

# %%
import numpy as np
import pandas as pd

# %%
ri = pd.read_csv("ri.csv",low_memory=False, index_col = "DatetimeIndex")

# %%
ri
# Out:
#                              id   stop_date stop_time location_raw  \
# DatetimeIndex
# 2005-01-02 01:55  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05  RI-2005-00006  2005-01-12     08:05      Zone X1
# ...                         ...         ...       ...          ...
# 2015-12-31 22:46  RI-2015-47061  2015-12-31     22:46      Zone X1
# 2015-12-31 22:47  RI-2015-47062  2015-12-31     22:47      Zone X4
# 2015-12-31 23:08  RI-2015-47063  2015-12-31     23:08      Zone X3
# 2015-12-31 23:44  RI-2015-47064  2015-12-31     23:44      Zone K2
# 2015-12-31 23:48  RI-2015-47065  2015-12-31     23:48      Zone K3
#
#                   county_fips  fine_grained_location police_department  \
# DatetimeIndex
# 2005-01-02 01:55          NaN                    NaN               600
# 2005-01-02 20:30          NaN                    NaN               500
# 2005-01-04 12:55          NaN                    NaN               500
# 2005-01-06 01:30          NaN                    NaN               500
# 2005-01-12 08:05          NaN                    NaN               000
# ...                       ...                    ...               ...
# 2015-12-31 22:46          NaN                    NaN               000
# 2015-12-31 22:47          NaN                    NaN               500
# 2015-12-31 23:08          NaN                    NaN               200
# 2015-12-31 23:44          NaN                    NaN               900
# 2015-12-31 23:48          NaN                    NaN               300
#
#                  driver_gender  driver_age_raw  driver_age  ...  \
# DatetimeIndex                                               ...
# 2005-01-02 01:55             M          1985.0        20.0  ...
# 2005-01-02 20:30             M          1987.0        18.0  ...
# 2005-01-04 12:55             M          1986.0        19.0  ...
# 2005-01-06 01:30             M          1978.0        27.0  ...
# 2005-01-12 08:05             M          1973.0        32.0  ...
# ...                        ...             ...         ...  ...
# 2015-12-31 22:46             M          1959.0        56.0  ...
# 2015-12-31 22:47             M          1988.0        27.0  ...
# 2015-12-31 23:08             M          1980.0        35.0  ...
# 2015-12-31 23:44             M          1984.0        31.0  ...
# 2015-12-31 23:48             M          1988.0        27.0  ...
#
#                  search_type_raw search_type contraband_found stop_outcome  \
# DatetimeIndex
# 2005-01-02 01:55             NaN         NaN            False     Citation
# 2005-01-02 20:30             NaN         NaN            False     Citation
# 2005-01-04 12:55             NaN         NaN            False     Citation
# 2005-01-06 01:30             NaN         NaN            False     Citation
# 2005-01-12 08:05             NaN         NaN            False     Citation
# ...                          ...         ...              ...          ...
# 2015-12-31 22:46             NaN         NaN            False     Citation
# 2015-12-31 22:47             NaN         NaN            False     Citation
# 2015-12-31 23:08             NaN         NaN            False     Citation
# 2015-12-31 23:44             NaN         NaN            False     Citation
# 2015-12-31 23:48             NaN         NaN            False     Citation
#
#                   is_arrested stop_duration out_of_state  drugs_related_stop  \
# DatetimeIndex
# 2005-01-02 01:55        False      0-15 Min        False               False
# 2005-01-02 20:30        False     16-30 Min        False               False
# 2005-01-04 12:55        False      0-15 Min        False               False
# 2005-01-06 01:30        False      0-15 Min        False               False
# 2005-01-12 08:05        False       30+ Min         True               False
# ...                       ...           ...          ...                 ...
# 2015-12-31 22:46        False      0-15 Min         True               False
# 2015-12-31 22:47        False      0-15 Min        False               False
# 2015-12-31 23:08        False      0-15 Min        False               False
# 2015-12-31 23:44        False      0-15 Min        False               False
# 2015-12-31 23:48        False      0-15 Min        False               False
#
#                  district  frisk
# DatetimeIndex
# 2005-01-02 01:55  Zone K1  False
# 2005-01-02 20:30  Zone X4  False
# 2005-01-04 12:55  Zone X4  False
# 2005-01-06 01:30  Zone X4  False
# 2005-01-12 08:05  Zone X1  False
# ...                   ...    ...
# 2015-12-31 22:46  Zone X1  False
# 2015-12-31 22:47  Zone X4  False
# 2015-12-31 23:08  Zone X3  False
# 2015-12-31 23:44  Zone K2  False
# 2015-12-31 23:48  Zone K3  False
#
# [480584 rows x 25 columns]

# %%
ri.head(5)
# Out:
#                              id   stop_date stop_time location_raw  \
# DatetimeIndex
# 2005-01-02 01:55  RI-2005-00001  2005-01-02     01:55      Zone K1
# 2005-01-02 20:30  RI-2005-00002  2005-01-02     20:30      Zone X4
# 2005-01-04 12:55  RI-2005-00004  2005-01-04     12:55      Zone X4
# 2005-01-06 01:30  RI-2005-00005  2005-01-06     01:30      Zone X4
# 2005-01-12 08:05  RI-2005-00006  2005-01-12     08:05      Zone X1
#
#                   county_fips  fine_grained_location police_department  \
# DatetimeIndex
# 2005-01-02 01:55          NaN                    NaN               600
# 2005-01-02 20:30          NaN                    NaN               500
# 2005-01-04 12:55          NaN                    NaN               500
# 2005-01-06 01:30          NaN                    NaN               500
# 2005-01-12 08:05          NaN                    NaN               000
#
#                  driver_gender  driver_age_raw  driver_age  ...  \
# DatetimeIndex                                               ...
# 2005-01-02 01:55             M          1985.0        20.0  ...
# 2005-01-02 20:30             M          1987.0        18.0  ...
# 2005-01-04 12:55             M          1986.0        19.0  ...
# 2005-01-06 01:30             M          1978.0        27.0  ...
# 2005-01-12 08:05             M          1973.0        32.0  ...
#
#                  search_type_raw search_type contraband_found stop_outcome  \
# DatetimeIndex
# 2005-01-02 01:55             NaN         NaN            False     Citation
# 2005-01-02 20:30             NaN         NaN            False     Citation
# 2005-01-04 12:55             NaN         NaN            False     Citation
# 2005-01-06 01:30             NaN         NaN            False     Citation
# 2005-01-12 08:05             NaN         NaN            False     Citation
#
#                   is_arrested stop_duration out_of_state  drugs_related_stop  \
# DatetimeIndex
# 2005-01-02 01:55        False      0-15 Min        False               False
# 2005-01-02 20:30        False     16-30 Min        False               False
# 2005-01-04 12:55        False      0-15 Min        False               False
# 2005-01-06 01:30        False      0-15 Min        False               False
# 2005-01-12 08:05        False       30+ Min         True               False
#
#                  district  frisk
# DatetimeIndex
# 2005-01-02 01:55  Zone K1  False
# 2005-01-02 20:30  Zone X4  False
# 2005-01-04 12:55  Zone X4  False
# 2005-01-06 01:30  Zone X4  False
# 2005-01-12 08:05  Zone X1  False
#
# [5 rows x 25 columns]

# %%
ri.isnull()
# Out:
#                      id  stop_date  stop_time  location_raw  county_fips  \
# DatetimeIndex
# 2005-01-02 01:55  False      False      False         False         True
# 2005-01-02 20:30  False      False      False         False         True
# 2005-01-04 12:55  False      False      False         False         True
# 2005-01-06 01:30  False      False      False         False         True
# 2005-01-12 08:05  False      False      False         False         True
# ...                 ...        ...        ...           ...          ...
# 2015-12-31 22:46  False      False      False         False         True
# 2015-12-31 22:47  False      False      False         False         True
# 2015-12-31 23:08  False      False      False         False         True
# 2015-12-31 23:44  False      False      False         False         True
# 2015-12-31 23:48  False      False      False         False         True
#
#                   fine_grained_location  police_department  driver_gender  \
# DatetimeIndex
# 2005-01-02 01:55                   True              False          False
# 2005-01-02 20:30                   True              False          False
# 2005-01-04 12:55                   True              False          False
# 2005-01-06 01:30                   True              False          False
# 2005-01-12 08:05                   True              False          False
# ...                                 ...                ...            ...
# 2015-12-31 22:46                   True              False          False
# 2015-12-31 22:47                   True              False          False
# 2015-12-31 23:08                   True              False          False
# 2015-12-31 23:44                   True              False          False
# 2015-12-31 23:48                   True              False          False
#
#                   driver_age_raw  driver_age  ...  search_type_raw  \
# DatetimeIndex                                 ...
# 2005-01-02 01:55           False       False  ...             True
# 2005-01-02 20:30           False       False  ...             True
# 2005-01-04 12:55           False       False  ...             True
# 2005-01-06 01:30           False       False  ...             True
# 2005-01-12 08:05           False       False  ...             True
# ...                          ...         ...  ...              ...
# 2015-12-31 22:46           False       False  ...             True
# 2015-12-31 22:47           False       False  ...             True
# 2015-12-31 23:08           False       False  ...             True
# 2015-12-31 23:44           False       False  ...             True
# 2015-12-31 23:48           False       False  ...             True
#
#                   search_type  contraband_found  stop_outcome  is_arrested  \
# DatetimeIndex
# 2005-01-02 01:55         True             False         False        False
# 2005-01-02 20:30         True             False         False        False
# 2005-01-04 12:55         True             False         False        False
# 2005-01-06 01:30         True             False         False        False
# 2005-01-12 08:05         True             False         False        False
# ...                       ...               ...           ...          ...
# 2015-12-31 22:46         True             False         False        False
# 2015-12-31 22:47         True             False         False        False
# 2015-12-31 23:08         True             False         False        False
# 2015-12-31 23:44         True             False         False        False
# 2015-12-31 23:48         True             False         False        False
#
#                   stop_duration  out_of_state  drugs_related_stop  district  \
# DatetimeIndex
# 2005-01-02 01:55          False         False               False     False
# 2005-01-02 20:30          False         False               False     False
# 2005-01-04 12:55          False         False               False     False
# 2005-01-06 01:30          False         False               False     False
# 2005-01-12 08:05          False         False               False     False
# ...                         ...           ...                 ...       ...
# 2015-12-31 22:46          False         False               False     False
# 2015-12-31 22:47          False         False               False     False
# 2015-12-31 23:08          False         False               False     False
# 2015-12-31 23:44          False         False               False     False
# 2015-12-31 23:48          False         False               False     False
#
#                   frisk
# DatetimeIndex
# 2005-01-02 01:55  False
# 2005-01-02 20:30  False
# 2005-01-04 12:55  False
# 2005-01-06 01:30  False
# 2005-01-12 08:05  False
# ...                 ...
# 2015-12-31 22:46  False
# 2015-12-31 22:47  False
# 2015-12-31 23:08  False
# 2015-12-31 23:44  False
# 2015-12-31 23:48  False
#
# [480584 rows x 25 columns]

# %%
ri.isnull().sum()
# Out:
# id                            0
# stop_date                     0
# stop_time                     0
# location_raw                  0
# county_fips              480584
# fine_grained_location    480584
# police_department             0
# driver_gender                 0
# driver_age_raw                1
# driver_age                 1638
# driver_race_raw               0
# driver_race                   0
# violation_raw                 0
# violation                     0
# search_conducted              0
# search_type_raw          462822
# search_type              462822
# contraband_found              0
# stop_outcome                  0
# is_arrested                   0
# stop_duration                 0
# out_of_state                808
# drugs_related_stop            0
# district                      0
# frisk                         0
# dtype: int64

# %%
ri.shape
# Out:
# (480584, 25)

# %%
ri.drop(["county_name"], axis = 1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-231150a954f6> in <module>
# ----> 1 ri.drop(["county_name"], axis = 1, inplace= True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5016         if mask.any():
#    5017             if errors != "ignore":
# -> 5018                 raise KeyError(f"{labels[mask]} not found in axis")
#    5019             indexer = indexer[~mask]
#    5020         return self.delete(indexer)
#
# KeyError: "['county_name'] not found in axis"

# %%
ri.shape

# %%
ri.drop(["state"], axis = 1, inplace= True)

# %%
ri.shape

# %%
ri.count(axis = "columns")

# %%
ri.dropna(axis=0,subset =["driver_gender"],inplace = True)

# %%
ri.shape

# %%
ri.is_arrested

# %%
ri["is_arrested"] = ri["is_arrested"].astype('bool')

# %%
ri["is_arrested"].dtype

# %%
ri.stop_date

# %%
ri.stop_time

# %%
ri['stop_datetime'] =  ri["stop_date"] +" "+  ri["stop_time"]

# %%
ri.set_index("stop_datetime", inplace=True)

# %%
ri.to_csv("ri_index_stop.csv")

# %%
ri.index.name = 'DatetimeIndex'

# %%
ri.head()

# %%
ri.to_csv("ri.csv")

# %%
ri

# %%
ri["violation"].unique()

# %%
ri["violation"].value_counts(normalize=True) * 100

# %%
female = ri[ri["driver_gender"] == "F"]

# %%
male = ri[ri["driver_gender"] == "M"]

# %%
ri["violation"].value_counts(normalize=True) * 100

# %%
female["violation"].value_counts(normalize =True)*100

# %%
male["violation"].value_counts(normalize =True)*100

# %%
female_and_speeding = female[female["violation"]=="Speeding"]

# %%
female_and_speeding["stop_outcome"].value_counts(normalize =True)*100

# %%
male_and_speeding = male[male["violation"]=="Speeding"]

# %%
male_and_speeding["stop_outcome"].value_counts(normalize =True)*100

# %%
ri["search_conducted"] = ri["search_conducted"].astype('bool')

# %%
ri["search_conducted"].value_counts(normalize =True)

# %%
ri["search_conducted"].mean()

# %%
female["search_conducted"].mean()

# %%
male["search_conducted"].mean()

# %%
ri.groupby("driver_gender")["search_conducted"].mean()

# %%
ri.groupby(["driver_gender", "violation"])[["search_conducted"]].mean()

# %%
ri.groupby(["violation", "driver_gender"])[["search_conducted"]].mean()

# %%
ri["search_type"].value_counts()["Protective Frisk"]

# %%
ri["frisk"] = (ri["search_type"]=="Protective Frisk")

# %%
ri["frisk"].dtype

# %%
ri["frisk"].sum()

# %%
searched= ri[ri["search_conducted"]== True]

# %%
searched

# %%
ri.groupby(["driver_gender"])["frisk"].mean()

# %%
searched["frisk"].mean()

# %%
ri.to_csv("ri.csv")

# %%
ri.head()
